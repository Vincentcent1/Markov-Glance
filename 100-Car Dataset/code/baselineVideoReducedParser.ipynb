# %%
import numpy as np
import pandas as pd

# %%
text_file = '../100CarBaselineVideoReducedData_v1_1/100CarBaselineVideoReducedData_v1_1.txt'

# %%
txt_file = pd.read_csv(text_file,sep='/n',header=None)
txt_df = txt_file[0].str.split('\t',expand=True)
column_names = ['Webfileid','Vehicle_webid','Subject_webid','Subject_age','Subject_gender','Epoch Start',' Epoch End',
                'Driver Behavior 1','Driver Behavior 2','Driver Behavior 3','Distraction 1','Distraction 2',
               'Distraction 3','Distraction 4','Distraction 5','Distraction 6','Surface Condition','Traffic Flow',
               'Travel Lanes','Traffic Density','Traffic Control','Relation to Junction','Alignment','Locality',
               'Lighting','Weather','Driver Seatbelt Use']
txt_df.columns = column_names
print(txt_df)
# Out:
# /home/vincent/virtualenvironment/markov/lib/python2.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#       Webfileid Vehicle_webid Subject_webid Subject_age Subject_gender  \
# 0         10001          1031          1033          54         Female
# 1         10002          2012             .           .
# 2         10003          1083          1052          43           Male
# 3         10004          1007          1026          43           Male
# 4         10005          1076          1067          43           Male
# 5         10006          1004             .           .
# 6         10007          1076          1067          43           Male
# ...
