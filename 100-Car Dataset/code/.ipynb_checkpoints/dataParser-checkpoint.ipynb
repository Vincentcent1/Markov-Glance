# %%
import numpy as np
import pandas as pd
import common_functions as cf

# %%
baseline_video = '../100CarBaselineVideoReducedData_v1_1/100CarBaselineVideoReducedData_v1_1.txt'
# txt_file = pd.read_csv(text_file,sep='/n',header=None)
# txt_df = txt_file[0].str.split('\t',expand=True)
baseline_video_df = cf.fileToDataFrame(baseline_video)


baseline_video_column_names = ['id','vehicleId','subjectId','subjectAge','subjectGender','epochStart','epochEnd',
                'driverBehavior1','driverBehavior2','driverBehavior3','distraction1','distraction2',
               'distraction3','distraction4','distraction5','distraction6','surfaceCondition','trafficFlow',
               'travelLanes','trafficDensity','trafficControl','relationToJunction','alignment','locality',
               'lighting','weather','driverSeatbeltUse']
baseline_video_df.columns = baseline_video_column_names
print(baseline_video_df[])

# %%
baseline_eyeglance = '../100CarBaselineEyeglanceData_v1_1/100CarBaselineEyeglanceData_v1_1.txt'
baseline_eyeglance_df = cf.fileToDataFrame(baseline_eyeglance)
baseline_eyeglance_column_names = ['id', 'beginSync', 'endSync', 'glanceDuration', 'glanceLocation']
baseline_eyeglance_df.columns = baseline_eyeglance_column_names
# print (baseline_eyeglance_df)

# %%
event_video = '../100CarEventVideoReducedData_v1_5/100CarEventVideoReducedData_v1_5.txt'
event_video_df = cf.fileToDataFrame(event_video)
# print (event_video_df)
event_video_df['driverImpairments'] = event_video_df.iloc[:,18:32].apply(lambda x: ','.join(x), axis=1).str.split(',')
print len(event_video_df['driverImpairments'][0])
event_video_df.drop(list(range(18,32)), axis = 1, inplace = True)
# print event_video_df['distraction1']
event_video_column_names = ['id','vehicleId','eventStart','eventEnd','eventSeverity','subjectId','subjectAge','subjectGender',
               'eventNature','incidentType','preIncidentManeuver','maneuverJudgement','precipitatingEvent','driverReaction', 
               'postManeuverControl','driverBehavior1','driverBehavior2','driverBehavior3',
               'infrastructure','distraction1','distraction1StartSync','distraction1EndSync','distraction1Outcome',
               'distraction2','distraction2StartSync','distraction2EndSync','distraction2Outcome','distraction3',
               'distraction3StartSync','distraction3EndSync','distraction3Outcome','handsOnTheWheel','vehicleContributingFactors','visualObstructions',
               'surfaceCondition','trafficFlow','travelLanes','trafficDensity','trafficControl','relationToJunction',
               'alignment','locality','lighting','weather','driverSeatbeltUse','numberOfOtherVehicles','fault',
               'vehicle2Location','vehicle2Type','vehicle2Maneuver','vehicle2DriverReaction','vehicle3Type','vehicle3Location',
                'vehicle3Maneuver','vehicle3DriverReaction','driverImpairments']
# print (len(event_video_df.columns))
# print event_video_df[32]

event_video_df.columns = event_video_column_names
event_video_df
# Out:
# 14
#        id vehicleId eventStart eventEnd eventSeverity subjectId subjectAge  \
# 0    8296      1038       1010     1050    Near-Crash      1061         23
# 1    8297      1038       2475     2530    Near-Crash      1061         23
# 2    8298      1016       8172     8283    Near-Crash         .          .
# 3    8299      1016       5411     5467    Near-Crash      1099         24
# 4    8300      1081       2490     2660    Near-Crash      1027         29
# 5    8301      1023       3600     3651    Near-Crash      1093         22
# 6    8302      1023         70      113         Crash      1093         22
# 7    8303      1081        600      640    Near-Crash      1091         19
# 8    8304      1075        667      740    Near-Crash      1016         20
# 9    8305      1016       7198     7272    Near-Crash      1099         24
# 10   8306      1016         58      140    Near-Crash      1099         24
# 11   8307      1016          0       80         Crash      1099         24
# 12   8308      1055       2816     2938    Near-Crash      1028         33
# 13   8309      1081        285      330    Near-Crash      1091         19
# 14   8310      1081        787      841    Near-Crash      1091         19
# 15   8311      1075      13634    13708    Near-Crash      1016         20
# 16   8312      1074      18132    18186    Near-Crash      1018         29
# 17   8313      1074       5869     5939         Crash      1018         29
# 18   8314      1051       2105     2150    Near-Crash      1077         24
# 19   8315      1051       4450     4502    Near-Crash      1077         24
# 20   8316      1014        256      285    Near-Crash         .          .
# 21   8317      1014      31276    31381    Near-Crash      1081         50
# 22   8318      1016          0       75    Near-Crash      1099         24
# 23   8319      1016        690      765    Near-Crash      1099         24
# 24   8320      1024      16325    16356    Near-Crash      1006         68
# 25   8321      1024      17839    17870    Near-Crash      1006         68
# 26   8322      1049       2196     2263         Crash      1032         19
# 27   8323      1049       2930     2983    Near-Crash      1032         19
# 28   8324      1006       5661     5689    Near-Crash      1092         20
# 29   8325      1055       9228     9280    Near-Crash      1028         33
# ..    ...       ...        ...      ...           ...       ...        ...
# 798  9094      1029      38720    38773    Near-Crash      1083         18
# 799  9095      1029      10541    10586    Near-Crash      1083         18
# 800  9096      1029       8718     8844    Near-Crash      1083         18
# 801  9097      1063       3478     3525    Near-Crash      1025         50
# 802  9098      1063       2788     2825    Near-Crash      1025         50
# 803  9099      1001      53254    53371    Near-Crash      1088         52
# 804  9100      1049      27845    27906    Near-Crash      1032         19
# 805  9101      1023       9715     9807    Near-Crash      1093         22
# 806  9102      1066       4457     4530    Near-Crash      1070         23
# 807  9103      1066      15180    15218         Crash      1070         23
# 808  9104      1017       4865     4907    Near-Crash      1071         20
# 809  9105      1017       6219     6243    Near-Crash      1071         20
# 810  9106      1017       1147     1172    Near-Crash      1071         20
# 811  9107      1017        327      377    Near-Crash      1071         20
# 812  9108      1017       7281     7321    Near-Crash      1071         20
# 813  9109      1017       4330     4375    Near-Crash      1071         20
# 814  9110      1017       3276     3326    Near-Crash      1071         20
# 815  9111      1020        913      941    Near-Crash      1085         20
# 816  9112      1020       4484     4527    Near-Crash      1085         20
# 817  9113      1020       8000     8055    Near-Crash      1085         20
# 818  9114      2004       3748     3835    Near-Crash      1029         40
# 819  9115      1020       3040     3076    Near-Crash      1085         20
# 820  9116      1020       5219     5268    Near-Crash      1085         20
# 821  9117      1020       6151     6304    Near-Crash      1085         20
# 822  9118      1020       7539     7612    Near-Crash      1085         20
# 823  9119      1020       9258     9277         Crash      1085         20
# 824  9120      1020       8548     8649    Near-Crash      1085         20
# 825  9121      1020      14607    14692    Near-Crash      1085         20
# 826  9122      1020      12539    12592    Near-Crash      1085         20
# 827  9123      1077       3265     3338         Crash      1013         51
#
#     subjectGender                                        eventNature  \
# 0          Female                       Conflict with a lead vehicle
# 1          Female                       Conflict with a lead vehicle
# 2                             Conflict with vehicle in adjacent lane
# 3          Female                            Single vehicle conflict
# 4          Female             Conflict with vehicle in adjacent lane
# 5            Male             Conflict with vehicle in adjacent lane
# 6            Male                            Single vehicle conflict
# 7            Male             Conflict with vehicle in adjacent lane
# 8          Female  Conflict with vehicle moving across another ve...
# 9          Female             Conflict with vehicle in adjacent lane
# 10         Female                       Conflict with a lead vehicle
# 11         Female                            Single vehicle conflict
# 12         Female  Conflict with vehicle moving across another ve...
# 13           Male                  Conflict with a following vehicle
# 14           Male                     Conflict with oncoming traffic
# 15         Female                       Conflict with a lead vehicle
# 16         Female                  Conflict with a following vehicle
# 17         Female                       Conflict with a lead vehicle
# 18         Female                            Single vehicle conflict
# 19         Female                  Conflict with a following vehicle
# 20                 Conflict with vehicle turning into another veh...
# 21           Male                       Conflict with a lead vehicle
# 22         Female                       Conflict with a lead vehicle
# 23         Female                  Conflict with a following vehicle
# 24           Male                       Conflict with a lead vehicle
# 25           Male                       Conflict with a lead vehicle
# 26         Female                       Conflict with a lead vehicle
# 27         Female             Conflict with vehicle in adjacent lane
# 28         Female  Conflict with vehicle turning across another v...
# 29         Female  Conflict with vehicle turning across another v...
# ..            ...                                                ...
# 798        Female             Conflict with vehicle in adjacent lane
# 799        Female  Conflict with vehicle turning into another veh...
# 800        Female                     Conflict with oncoming traffic
# 801        Female                       Conflict with a lead vehicle
# 802        Female                       Conflict with a lead vehicle
# 803        Female  Conflict with vehicle turning across another v...
# 804        Female                       Conflict with a lead vehicle
# 805          Male                       Conflict with a lead vehicle
# 806          Male                     Conflict with oncoming traffic
# 807          Male                            Single vehicle conflict
# 808          Male  Conflict with vehicle turning across another v...
# 809          Male                       Conflict with a lead vehicle
# 810          Male                            Single vehicle conflict
# 811          Male                       Conflict with a lead vehicle
# 812          Male                       Conflict with a lead vehicle
# 813          Male                       Conflict with a lead vehicle
# 814          Male                       Conflict with a lead vehicle
# 815          Male                       Conflict with a lead vehicle
# 816          Male                       Conflict with a lead vehicle
# 817          Male                       Conflict with a lead vehicle
# 818          Male                       Conflict with a lead vehicle
# 819          Male                     Conflict with oncoming traffic
# 820          Male  Conflict with vehicle moving across another ve...
# 821          Male                     Conflict with oncoming traffic
# 822          Male                     Conflict with oncoming traffic
# 823          Male                               Conflict with animal
# 824          Male                       Conflict with a lead vehicle
# 825          Male                       Conflict with a lead vehicle
# 826          Male                       Conflict with a lead vehicle
# 827          Male                  Conflict with a following vehicle
#
#                                           incidentType  \
# 0                                   Rear-end, striking
# 1                                   Rear-end, striking
# 2            Sideswipe, same direction (left or right)
# 3                       Road departure (left or right)
# 4            Sideswipe, same direction (left or right)
# 5            Sideswipe, same direction (left or right)
# 6                                                Other
# 7            Sideswipe, same direction (left or right)
# 8    Straight crossing path, not involving sign/sig...
# 9            Sideswipe, same direction (left or right)
# 10                                  Rear-end, striking
# 11                      Road departure (left or right)
# 12           Opposite direction (head-on or sideswipe)
# 13                                    Rear-end, struck
# 14           Opposite direction (head-on or sideswipe)
# 15                                  Rear-end, striking
# 16                                    Rear-end, struck
# 17                                  Rear-end, striking
# 18                      Road departure (left or right)
# 19                                    Rear-end, struck
# 20                 Turn into path (opposite direction)
# 21                                  Rear-end, striking
# 22                                  Rear-end, striking
# 23                                    Rear-end, struck
# 24                                  Rear-end, striking
# 25                                  Rear-end, striking
# 26                                  Rear-end, striking
# 27           Sideswipe, same direction (left or right)
# 28                                    Turn across path
# 29                 Turn into path (opposite direction)
# ..                                                 ...
# 798          Sideswipe, same direction (left or right)
# 799                    Turn into path (same direction)
# 800          Opposite direction (head-on or sideswipe)
# 801                                 Rear-end, striking
# 802                                 Rear-end, striking
# 803          Opposite direction (head-on or sideswipe)
# 804                                 Rear-end, striking
# 805                                 Rear-end, striking
# 806          Opposite direction (head-on or sideswipe)
# 807                     Road departure (left or right)
# 808                                   Turn across path
# 809                                 Rear-end, striking
# 810                     Road departure (left or right)
# 811                                 Rear-end, striking
# 812                                 Rear-end, striking
# 813                                 Rear-end, striking
# 814                                 Rear-end, striking
# 815                                 Rear-end, striking
# 816                                 Rear-end, striking
# 817                                 Rear-end, striking
# 818                                 Rear-end, striking
# 819          Opposite direction (head-on or sideswipe)
# 820                                   Turn across path
# 821          Opposite direction (head-on or sideswipe)
# 822          Opposite direction (head-on or sideswipe)
# 823                                             Animal
# 824                                 Rear-end, striking
# 825                                 Rear-end, striking
# 826                                 Rear-end, striking
# 827                                   Rear-end, struck
#
#                            ...                                   fault  \
# 0                          ...                          Subject Driver
# 1                          ...                                Driver 2
# 2                          ...                          Subject Driver
# 3                          ...                          Subject Driver
# 4                          ...                          Subject Driver
# 5                          ...                          Subject Driver
# 6                          ...                                 Unknown
# 7                          ...                          Subject Driver
# 8                          ...                                Driver 2
# 9                          ...                          Subject Driver
# 10                         ...                                Driver 2
# 11                         ...                          Subject Driver
# 12                         ...                                 Unknown
# 13                         ...                                Driver 2
# 14                         ...                          Subject Driver
# 15                         ...                                 Unknown
# 16                         ...                                 Unknown
# 17                         ...                          Subject Driver
# 18                         ...                          Subject Driver
# 19                         ...                                 Unknown
# 20                         ...                                Driver 2
# 21                         ...                                 Unknown
# 22                         ...                          Subject Driver
# 23                         ...                          Subject Driver
# 24                         ...                                Driver 2
# 25                         ...                                Driver 2
# 26                         ...                          Subject Driver
# 27                         ...                                 Unknown
# 28                         ...                                Driver 2
# 29                         ...                                Driver 2
# ..                         ...                                     ...
# 798                        ...                                Driver 2
# 799                        ...                                Driver 2
# 800                        ...                                 Unknown
# 801                        ...                                Driver 2
# 802                        ...                                 Unknown
# 803                        ...                                Driver 2
# 804                        ...                          Subject Driver
# 805                        ...                          Subject Driver
# 806                        ...                                 Unknown
# 807                        ...                          Subject Driver
# 808                        ...                                Driver 2
# 809                        ...                                Driver 2
# 810                        ...                          Subject Driver
# 811                        ...                          Subject Driver
# 812                        ...                                Driver 2
# 813                        ...                          Subject Driver
# 814                        ...                          Subject Driver
# 815                        ...                                Driver 2
# 816                        ...                          Subject Driver
# 817                        ...                          Subject Driver
# 818                        ...                          Subject Driver
# 819                        ...                          Subject Driver
# 820                        ...                          Subject Driver
# 821                        ...                          Subject Driver
# 822                        ...                          Subject Driver
# 823                        ...                                 Unknown
# 824                        ...                                 Unknown
# 825                        ...                          Subject Driver
# 826                        ...                          Subject Driver
# 827                        ...                                Driver 2
#
#                                       vehicle2Location  \
# 0                      A = In front of subject vehicle
# 1    B = In front and to the immediate right of the...
# 2    G = Behind and to the immediate left of the su...
# 3    I = On the left side of the subject vehicle, c...
# 4    I = On the left side of the subject vehicle, c...
# 5    B = In front and to the immediate right of the...
# 6    I = On the left side of the subject vehicle, c...
# 7    I = On the left side of the subject vehicle, c...
# 8    B = In front and to the immediate right of the...
# 9    D = On the right side of the subject vehicle, ...
# 10   J = In front and to the immediate left of the ...
# 11                                    No analyzed data
# 12   J = In front and to the immediate left of the ...
# 13                      F = Behind the subject vehicle
# 14                     A = In front of subject vehicle
# 15                     A = In front of subject vehicle
# 16                      F = Behind the subject vehicle
# 17                     A = In front of subject vehicle
# 18                                    No analyzed data
# 19                     A = In front of subject vehicle
# 20   B = In front and to the immediate right of the...
# 21   B = In front and to the immediate right of the...
# 22                     A = In front of subject vehicle
# 23                      F = Behind the subject vehicle
# 24   B = In front and to the immediate right of the...
# 25   J = In front and to the immediate left of the ...
# 26                     A = In front of subject vehicle
# 27   J = In front and to the immediate left of the ...
# 28                     A = In front of subject vehicle
# 29   J = In front and to the immediate left of the ...
# ..                                                 ...
# 798  I = On the left side of the subject vehicle, c...
# 799  J = In front and to the immediate left of the ...
# 800                    A = In front of subject vehicle
# 801  J = In front and to the immediate left of the ...
# 802                    A = In front of subject vehicle
# 803  J = In front and to the immediate left of the ...
# 804                    A = In front of subject vehicle
# 805                    A = In front of subject vehicle
# 806                    A = In front of subject vehicle
# 807                                   No analyzed data
# 808                    A = In front of subject vehicle
# 809  J = In front and to the immediate left of the ...
# 810                                   No analyzed data
# 811                    A = In front of subject vehicle
# 812  B = In front and to the immediate right of the...
# 813                    A = In front of subject vehicle
# 814                    A = In front of subject vehicle
# 815  B = In front and to the immediate right of the...
# 816                    A = In front of subject vehicle
# 817                    A = In front of subject vehicle
# 818                    A = In front of subject vehicle
# 819  J = In front and to the immediate left of the ...
# 820  J = In front and to the immediate left of the ...
# 821                                   No analyzed data
# 822                    A = In front of subject vehicle
# 823                    A = In front of subject vehicle
# 824                    A = In front of subject vehicle
# 825                    A = In front of subject vehicle
# 826                    A = In front of subject vehicle
# 827                     F = Behind the subject vehicle
#
#                         vehicle2Type                    vehicle2Maneuver  \
# 0                         Automobile             Stopped in traffic lane
# 1                         Automobile                      Changing lanes
# 2                       Pickup truck                 Negotiating a curve
# 3      Tractor-trailer: Enclosed box      Going straight, constant speed
# 4                       Pickup truck      Going straight, constant speed
# 5                         Automobile          Entering a parked position
# 6                         Automobile             Stopped in traffic lane
# 7                         Automobile      Going straight, constant speed
# 8                         Automobile            Starting in traffic lane
# 9                         Automobile  Going straight ahead, accelerating
# 10            Sport Utility Vehicles                             Merging
# 11                  No analyzed data                    No analyzed data
# 12                        Automobile                        Turning left
# 13            Sport Utility Vehicles        Decelerating in traffic lane
# 14            Sport Utility Vehicles      Going straight, constant speed
# 15                        Automobile        Decelerating in traffic lane
# 16                        Automobile      Going straight, constant speed
# 17                        Automobile             Stopped in traffic lane
# 18                  No analyzed data                    No analyzed data
# 19                        Automobile             Stopped in traffic lane
# 20                        Automobile                        Turning left
# 21     Van (minivan or standard van)                      Changing lanes
# 22                        Automobile             Stopped in traffic lane
# 23            Sport Utility Vehicles      Going straight, constant speed
# 24                        Automobile                      Changing lanes
# 25                        Automobile                      Changing lanes
# 26                        Automobile             Stopped in traffic lane
# 27                        Automobile             Stopped in traffic lane
# 28                        Automobile                        Turning left
# 29            Sport Utility Vehicles                        Turning left
# ..                               ...                                 ...
# 798    Van (minivan or standard van)                      Changing lanes
# 799           Sport Utility Vehicles                        Turning left
# 800                 No analyzed data                    No analyzed data
# 801                       Automobile                      Changing lanes
# 802                       Automobile        Decelerating in traffic lane
# 803                       Automobile                        Turning left
# 804                     Pickup truck        Decelerating in traffic lane
# 805  Single-unit straight truck: Box        Decelerating in traffic lane
# 806           Sport Utility Vehicles                        Turning left
# 807                 No analyzed data                    No analyzed data
# 808           Sport Utility Vehicles                        Turning left
# 809                      Transit bus                      Changing lanes
# 810                 No analyzed data                    No analyzed data
# 811           Sport Utility Vehicles        Decelerating in traffic lane
# 812                       Automobile                      Changing lanes
# 813    Van (minivan or standard van)        Decelerating in traffic lane
# 814                       Automobile        Decelerating in traffic lane
# 815                       Automobile                      Changing lanes
# 816                       Automobile        Decelerating in traffic lane
# 817                       Automobile        Decelerating in traffic lane
# 818                       Automobile        Decelerating in traffic lane
# 819               Other vehicle type      Going straight, constant speed
# 820                       Automobile      Going straight, constant speed
# 821                 No analyzed data                    No analyzed data
# 822                       Automobile      Going straight, constant speed
# 823                           Animal                               Other
# 824                       Automobile        Decelerating in traffic lane
# 825           Sport Utility Vehicles        Decelerating in traffic lane
# 826           Sport Utility Vehicles        Decelerating in traffic lane
# 827           Sport Utility Vehicles      Going straight, constant speed
#
#               vehicle2DriverReaction  \
# 0                        No reaction
# 1                        Accelerated
# 2                        No reaction
# 3                        No reaction
# 4                        No reaction
# 5                        No reaction
# 6                        No reaction
# 7    Unknown if action was attempted
# 8                   Braking (lockup)
# 9    Unknown if action was attempted
# 10          Braking (lockup unknown)
# 11                  No analyzed data
# 12               Braking (no lockup)
# 13               Braking (no lockup)
# 14   Unknown if action was attempted
# 15                       No reaction
# 16               Braking (no lockup)
# 17                       No reaction
# 18                  No analyzed data
# 19                       No reaction
# 20   Unknown if action was attempted
# 21               Braking (no lockup)
# 22                       Accelerated
# 23               Braking (no lockup)
# 24                       No reaction
# 25   Unknown if action was attempted
# 26                       No reaction
# 27                   Steered to left
# 28                       No reaction
# 29               Braking (no lockup)
# ..                               ...
# 798                  Steered to left
# 799              Braking (no lockup)
# 800                 No analyzed data
# 801                  Steered to left
# 802                      No reaction
# 803         Braking (lockup unknown)
# 804                      No reaction
# 805                      No reaction
# 806                  Steered to left
# 807                 No analyzed data
# 808                      No reaction
# 809                      No reaction
# 810                 No analyzed data
# 811                      No reaction
# 812                      No reaction
# 813                      No reaction
# 814                      No reaction
# 815                 Steered to right
# 816                      No reaction
# 817              Braking (no lockup)
# 818              Braking (no lockup)
# 819  Unknown if action was attempted
# 820              Braking (no lockup)
# 821                 No analyzed data
# 822      Braked and steered to right
# 823                    Other actions
# 824                      No reaction
# 825                      No reaction
# 826                      No reaction
# 827  Unknown if action was attempted
#
#                                           vehicle3Type  \
# 0                                     No analyzed data
# 1                                     No analyzed data
# 2                      A = In front of subject vehicle
# 3                                     No analyzed data
# 4                                     No analyzed data
# 5    H = On the left side of the subject vehicle, c...
# 6                                     No analyzed data
# 7                                     No analyzed data
# 8    H = On the left side of the subject vehicle, c...
# 9                                     No analyzed data
# 10                                    No analyzed data
# 11                                    No analyzed data
# 12                                    No analyzed data
# 13   D = On the right side of the subject vehicle, ...
# 14   C = On the right side of the subject vehicle, ...
# 15   I = On the left side of the subject vehicle, c...
# 16                     A = In front of subject vehicle
# 17                      F = Behind the subject vehicle
# 18                                    No analyzed data
# 19                      F = Behind the subject vehicle
# 20                                    No analyzed data
# 21                                    No analyzed data
# 22                                    No analyzed data
# 23   B = In front and to the immediate right of the...
# 24                      F = Behind the subject vehicle
# 25                                    No analyzed data
# 26                                    No analyzed data
# 27                                    No analyzed data
# 28                                    No analyzed data
# 29                                    No analyzed data
# ..                                                 ...
# 798                                   No analyzed data
# 799                                   No analyzed data
# 800                                   No analyzed data
# 801                    A = In front of subject vehicle
# 802  E = Behind and to the immediate right of the s...
# 803                                   No analyzed data
# 804                                   No analyzed data
# 805                                   No analyzed data
# 806                                   No analyzed data
# 807                                   No analyzed data
# 808  C = On the right side of the subject vehicle, ...
# 809                                   No analyzed data
# 810                                   No analyzed data
# 811                                   No analyzed data
# 812                                   No analyzed data
# 813                                   No analyzed data
# 814                     F = Behind the subject vehicle
# 815                                   No analyzed data
# 816                                   No analyzed data
# 817                                   No analyzed data
# 818                     F = Behind the subject vehicle
# 819                                   No analyzed data
# 820                                   No analyzed data
# 821                                   No analyzed data
# 822                                   No analyzed data
# 823                                   No analyzed data
# 824                                   No analyzed data
# 825  J = In front and to the immediate left of the ...
# 826                     F = Behind the subject vehicle
# 827                    A = In front of subject vehicle
#
#                         vehicle3Location                vehicle3Maneuver  \
# 0                       No analyzed data                No analyzed data
# 1                       No analyzed data                No analyzed data
# 2                             Automobile         Stopped in traffic lane
# 3                       No analyzed data                No analyzed data
# 4                       No analyzed data                No analyzed data
# 5                             Automobile  Going straight, constant speed
# 6                       No analyzed data                No analyzed data
# 7                       No analyzed data                No analyzed data
# 8                             Automobile  Going straight, constant speed
# 9                       No analyzed data                No analyzed data
# 10                      No analyzed data                No analyzed data
# 11                      No analyzed data                No analyzed data
# 12                      No analyzed data                No analyzed data
# 13                 Sport Utility Vehicle         Stopped in traffic lane
# 14   Single-unit straight truck: Flatbed         Stopped in traffic lane
# 15                            Automobile  Going straight, constant speed
# 16                            Automobile         Stopped in traffic lane
# 17                            Automobile    Decelerating in traffic lane
# 18                      No analyzed data                No analyzed data
# 19                            Automobile                         Unknown
# 20                      No analyzed data                No analyzed data
# 21                      No analyzed data                No analyzed data
# 22                      No analyzed data                No analyzed data
# 23                            Automobile                         Merging
# 24                            Automobile        Starting in traffic lane
# 25                      No analyzed data                No analyzed data
# 26                      No analyzed data                No analyzed data
# 27                      No analyzed data                No analyzed data
# 28                      No analyzed data                No analyzed data
# 29                      No analyzed data                No analyzed data
# ..                                   ...                             ...
# 798                     No analyzed data                No analyzed data
# 799                     No analyzed data                No analyzed data
# 800                     No analyzed data                No analyzed data
# 801                Sport Utility Vehicle    Decelerating in traffic lane
# 802        Van (minivan or standard van)    Going straight, accelerating
# 803                     No analyzed data                No analyzed data
# 804                     No analyzed data                No analyzed data
# 805                     No analyzed data                No analyzed data
# 806                     No analyzed data                No analyzed data
# 807                     No analyzed data                No analyzed data
# 808                           Automobile    Decelerating in traffic lane
# 809                     No analyzed data                No analyzed data
# 810                     No analyzed data                No analyzed data
# 811                     No analyzed data                No analyzed data
# 812                     No analyzed data                No analyzed data
# 813                     No analyzed data                No analyzed data
# 814        Van (minivan or standard van)    Going straight, accelerating
# 815                     No analyzed data                No analyzed data
# 816                     No analyzed data                No analyzed data
# 817                     No analyzed data                No analyzed data
# 818                           Automobile    Decelerating in traffic lane
# 819                     No analyzed data                No analyzed data
# 820                     No analyzed data                No analyzed data
# 821                     No analyzed data                No analyzed data
# 822                     No analyzed data                No analyzed data
# 823                     No analyzed data                No analyzed data
# 824                     No analyzed data                No analyzed data
# 825                           Automobile  Going straight, constant speed
# 826                           Automobile  Going straight, constant speed
# 827                           Automobile         Stopped in traffic lane
#
#               vehicle3DriverReaction  \
# 0                   No analyzed data
# 1                   No analyzed data
# 2                        No reaction
# 3                   No analyzed data
# 4                   No analyzed data
# 5                    Steered to left
# 6                   No analyzed data
# 7                   No analyzed data
# 8                        No reaction
# 9                   No analyzed data
# 10                  No analyzed data
# 11                  No analyzed data
# 12                  No analyzed data
# 13                       No reaction
# 14                       No reaction
# 15                       No reaction
# 16                       No reaction
# 17               Braking (no lockup)
# 18                  No analyzed data
# 19          Braking (lockup unknown)
# 20                  No analyzed data
# 21                  No analyzed data
# 22                  No analyzed data
# 23   Unknown if action was attempted
# 24               Braking (no lockup)
# 25                  No analyzed data
# 26                  No analyzed data
# 27                  No analyzed data
# 28                  No analyzed data
# 29                  No analyzed data
# ..                               ...
# 798                 No analyzed data
# 799                 No analyzed data
# 800                 No analyzed data
# 801                      No reaction
# 802              Braking (no lockup)
# 803                 No analyzed data
# 804                 No analyzed data
# 805                 No analyzed data
# 806                 No analyzed data
# 807                 No analyzed data
# 808              Braking (no lockup)
# 809                 No analyzed data
# 810                 No analyzed data
# 811                 No analyzed data
# 812                 No analyzed data
# 813                 No analyzed data
# 814              Braking (no lockup)
# 815                 No analyzed data
# 816                 No analyzed data
# 817                 No analyzed data
# 818              Braking (no lockup)
# 819                 No analyzed data
# 820                 No analyzed data
# 821                 No analyzed data
# 822                 No analyzed data
# 823                 No analyzed data
# 824                 No analyzed data
# 825                      No reaction
# 826              Braking (no lockup)
# 827                      Accelerated
#
#                                      driverImpairments
# 0    [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 1    [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 2    [No, No, No, No, No, No, No, No, No, No, No, N...
# 3    [No, No, No, No, No, No, No, No, No, No, No, N...
# 4    [No, No, No, No, No, No, No, No, No, No, No, N...
# 5    [No, No, No, No, No, No, No, No, No, No, No, N...
# 6    [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 7    [No, No, No, No, No, No, No, No, No, No, No, N...
# 8    [No, No, No, No, No, No, No, No, No, No, No, N...
# 9    [No, No, No, No, No, No, No, No, No, No, No, N...
# 10   [No, No, No, No, No, No, No, No, No, No, No, N...
# 11   [No, No, No, No, No, No, No, No, No, No, No, N...
# 12   [No, No, No, No, No, No, No, No, No, No, No, N...
# 13   [No, No, No, No, No, No, No, No, No, No, No, N...
# 14   [No, No, No, No, No, No, No, No, No, No, No, N...
# 15   [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 16   [No, No, No, No, No, No, No, No, No, No, No, N...
# 17   [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 18   [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 19   [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 20   [No, No, No, No, No, No, No, No, No, No, No, N...
# 21   [No, No, No, No, No, No, No, No, No, No, No, N...
# 22   [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 23   [No, No, No, No, No, No, No, No, No, No, No, N...
# 24   [No, No, No, No, No, No, No, No, No, No, No, N...
# 25   [No, No, No, No, No, No, No, No, No, No, No, N...
# 26   [No, No, No, No, No, No, No, No, No, No, No, N...
# 27   [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 28   [No, No, No, No, No, No, No, No, No, No, No, N...
# 29   [No, No, No, No, No, No, No, No, No, No, No, N...
# ..                                                 ...
# 798  [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 799  [Yes, No, No, No, No, No, No, No, No, No, No, ...
# 800  [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 801  [No, No, No, No, No, No, No, No, No, No, No, N...
# 802  [No, No, No, No, No, No, No, No, No, No, No, N...
# 803  [No, No, No, No, No, No, No, No, No, No, No, N...
# 804  [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 805  [No, No, No, No, No, No, No, No, No, No, No, N...
# 806  [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 807  [No, No, No, No, No, No, No, No, No, No, No, N...
# 808  [No, No, No, No, No, No, No, No, No, No, No, N...
# 809  [No, No, No, No, No, No, No, No, No, No, No, N...
# 810  [No, No, No, No, No, No, No, No, No, No, No, N...
# 811  [No, No, No, No, No, No, No, No, No, No, No, N...
# 812  [No, No, No, No, No, No, No, No, No, No, No, N...
# 813  [No, No, No, No, No, No, No, No, No, No, No, N...
# 814  [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 815  [No, No, No, No, No, No, No, No, No, No, No, N...
# 816  [No, No, No, No, No, No, No, No, No, No, No, N...
# 817  [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 818  [No, No, No, No, No, No, No, No, No, No, No, N...
# 819  [No, No, No, No, No, No, No, No, No, No, Yes, ...
# 820  [No, No, No, No, No, No, No, No, No, No, No, N...
# 821  [Yes, No, No, No, No, No, Yes, No, No, No, No,...
# 822  [Yes, No, No, No, No, No, No, No, No, No, No, ...
# 823  [No, No, No, No, No, No, No, No, No, No, No, N...
# 824  [No, No, No, No, No, No, No, No, No, No, No, N...
# 825  [No, No, No, No, No, No, No, No, No, No, No, N...
# 826  [No, No, No, No, No, No, No, No, No, No, No, N...
# 827  [No, No, No, No, No, No, No, No, No, No, No, N...
#
# [828 rows x 56 columns]

# %%
event_eyeglance = '../100CarEventEyeglanceData_v1_3/100CarEventEyeglanceData_v1_3.txt'
event_eyeglance_df = cf.fileToDataFrame(event_eyeglance)
event_eyeglance_column_names = ['id', 'beginSync', 'endSync', 'glanceDuration', 'glanceLocation']
event_eyeglance_df.columns = event_eyeglance_column_names

# %%
event_video = '../100CarEventVideoReducedData_v1_5/100CarEventVideoReducedData_v1_5.txt'
with open(event_video) as f:
    a = f.readlines()[0].split('\t')
    event_video_column_names = np.pad(event_video_column_names,[0,12],'constant')
    print(zip(a,event_video_column_names))
# Out:
# [('8296', 'id'), ('1038', 'vehicleId'), ('1010', 'eventStart'), ('1050', 'eventEnd'), ('Near-Crash', 'eventSeverity'), ('1061', 'subjectId'), ('23', 'subjectAge'), ('Female', 'subjectGender'), ('Conflict with a lead vehicle', 'eventNature'), ('Rear-end, striking', 'incidentType'), ('Decelerating in traffic lane', 'preIncidentManeuver'), ('Safe and legal', 'maneuverJudgement'), ('Other vehicle ahead - stopped on roadway more than 2 seconds', 'precipitatingEvent'), ('Braking (no lockup)', 'driverReaction'), ('Control maintained', 'postManeuverControl'), ('Inattentive or distracted', 'driverBehavior1'), ('Sudden or improper stopping on roadway', 'driverBehavior2'), ('None', 'driverBehavior3'), ('No', 'infrastructure'), ('No', 'distraction1'), ('No', 'distraction1StartSync'), ('No', 'distraction1EndSync'), ('No', 'distraction1Outcome'), ('No', 'distraction2'), ('No', 'distraction2StartSync'), ('No', 'distraction2EndSync'), ('No', 'distraction2Outcome'), ('No', 'distraction3'), ('Yes', 'distraction3StartSync'), ('No', 'distraction3EndSync'), ('No', 'distraction3Outcome'), ('No', 'handsOnTheWheel'), ('None', 'vehicleContributingFactors'), ('Dialing hand-held cell phone', 'visualObstructions'), ('940', 'surfaceCondition'), ('1080', 'trafficFlow'), ('Yes', 'travelLanes'), ('Adjusting radio', 'trafficDensity'), ('936', 'trafficControl'), ('1100', 'relationToJunction'), ('Yes', 'alignment'), ('Not Distracted', 'locality'), ('0', 'lighting'), ('0', 'weather'), ('No analyzed data', 'driverSeatbeltUse'), ('None', 'numberOfOtherVehicles'), ('No vehicle factors', 'fault'), ('No obstruction', 'vehicle2Location'), ('Dry', 'vehicle3Location'), ('Divided (median strip or barrier)', 'vehicle2Type'), ('4', 'vehicle3Type'), ('Level-of-service B: Flow with some restrictions', 'vehicle2Maneuver'), ('Traffic signal', 'vehicle3Maneuver'), ('Intersection-related', 'vehicle2DriverReaction'), ('Straight level', 'vehicle3DriverReaction'), ('Business/industrial', 'finalNarrative'), ('Darkness, lighted', 'driverImpairments'), ('Clear', ''), ('Lap/shoulder belt', ''), ('1', ''), ('Subject Driver', ''), ('A = In front of subject vehicle', ''), ('Automobile', ''), ('Stopped in traffic lane', ''), ('No reaction', ''), ('No analyzed data', ''), ('No analyzed data', ''), ('No analyzed data', ''), ('No analyzed data\r\n', '')]
